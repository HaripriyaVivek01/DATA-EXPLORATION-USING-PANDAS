# %% [markdown]
# ## DATA EXPLORATION USING PANDAS

# %% [markdown]
# ### This dataset is  downloaded from the kaggle dataset website and used it to do some basic data exploration using pandas. This dataset contains the world population data of every Country/Territories in the world.

# %%
import pandas as pd

# %% [markdown]
# ### We do some basic operations to this dataset, so import a library pandas as pd

# %%
world_population=pd.read_csv('C://Users//LENOVO//Downloads//world_population.csv')

# %% [markdown]
# ### Use pd.read_csv function to read the dataset.

# %%
world_population
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %% [markdown]
# ### To view the read dataset, use the dataset name world_population

# %%
world_population.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %% [markdown]
# ### The first five observations of the dataset

# %%
world_population.tail()
# Out:
#      Rank CCA3  Country/Territory   Capital Continent  2022 Population  \
# 229   226  WLF  Wallis and Futuna  Mata-Utu   Oceania            11572
# 230   172  ESH     Western Sahara  El Aaiún    Africa           575986
# 231    46  YEM              Yemen     Sanaa      Asia         33696614
# 232    63  ZMB             Zambia    Lusaka    Africa         20017675
# 233    74  ZWE           Zimbabwe    Harare    Africa         16320537
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 229            11655            12182            13142            14723
# 230           556048           491824           413296           270375
# 231         32284046         28516545         24743946         18628700
# 232         18927715         16248230         13792086          9891136
# 233         15669666         14154937         12839771         11834676
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %% [markdown]
# ### The last five observations of the dataset

# %%
world_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %% [markdown]
# ### To know memory and columnwise datatype.

# %%
world_population.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %% [markdown]
# ### To view basic statistical functions

# %%
world_population.shape
# Out:
# (234, 17)

# %% [markdown]
# ### 234 Observations and 17 variables of this dataset

# %%
world_population.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %% [markdown]
# ### Observations

# %%
world_population.index
# Out:
# RangeIndex(start=0, stop=234, step=1)

# %% [markdown]
# ### Range index starts from 0 and ends in 234.

# %%
world_population.sort_values(['2022 Population'],ascending=True)
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 226   234  VAT      Vatican City      Vatican City         Europe
# 209   233  TKL           Tokelau          Nukunonu        Oceania
# 150   232  NIU              Niue             Alofi        Oceania
# 64    231  FLK  Falkland Islands           Stanley  South America
# 137   230  MSR        Montserrat            Brades  North America
# ..    ...  ...               ...               ...            ...
# 156     5  PAK          Pakistan         Islamabad           Asia
# 93      4  IDN         Indonesia           Jakarta           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 92      2  IND             India         New Delhi           Asia
# 41      1  CHN             China           Beijing           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 226              510              520              564              596
# ...

# %% [markdown]
# ### The data's 2022 population to 1970 population in a ascending order.

# %%
world_population.sort_values(['Rank'],ascending=False)
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 226   234  VAT      Vatican City      Vatican City         Europe
# 209   233  TKL           Tokelau          Nukunonu        Oceania
# 150   232  NIU              Niue             Alofi        Oceania
# 64    231  FLK  Falkland Islands           Stanley  South America
# 137   230  MSR        Montserrat            Brades  North America
# ..    ...  ...               ...               ...            ...
# 156     5  PAK          Pakistan         Islamabad           Asia
# 93      4  IDN         Indonesia           Jakarta           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 92      2  IND             India         New Delhi           Asia
# 41      1  CHN             China           Beijing           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 226              510              520              564              596
# ...

# %% [markdown]
# ### Rank in descending order.

# %%
world_population['Continent'].value_counts()
# Out:
# Africa           57
# Asia             50
# Europe           50
# North America    40
# Oceania          23
# South America    14
# Name: Continent, dtype: int64

# %% [markdown]
# ### Count of Continent in dataset.

# %%
world_population.drop_duplicates(inplace=True)

# %%
world_population
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %% [markdown]
# ### No duplicates found in the dataset.

# %%
world_population_subset=world_population[['Rank','Continent']]

# %%
world_population_subset
# Out:
#      Rank Continent
# 0      36      Asia
# 1     138    Europe
# 2      34    Africa
# 3     213   Oceania
# 4     203    Europe
# ..    ...       ...
# 229   226   Oceania
# 230   172    Africa
# 231    46      Asia
# 232    63    Africa
# 233    74    Africa
#
# [234 rows x 2 columns]

# %% [markdown]
# ### column subset created of this dataset.

# %%
world_population_row=world_population[world_population['Rank']>150]

# %% [markdown]
# ### To view row of conditioned dataset by using world_population

# %%
world_population_row
# Out:
#      Rank CCA3             Country/Territory           Capital      Continent  \
# 3     213  ASM                American Samoa         Pago Pago        Oceania
# 4     203  AND                       Andorra  Andorra la Vella         Europe
# 6     224  AIA                      Anguilla        The Valley  North America
# 7     201  ATG           Antigua and Barbuda      Saint John’s  North America
# 10    198  ABW                         Aruba        Oranjestad  North America
# ..    ...  ...                           ...               ...            ...
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
# 225   181  VUT                       Vanuatu         Port-Vila        Oceania
# 226   234  VAT                  Vatican City      Vatican City         Europe
# 229   226  WLF             Wallis and Futuna          Mata-Utu        Oceania
# 230   172  ESH                Western Sahara          El Aaiún         Africa
#
# ...

# %% [markdown]
# ### To view Row subset of this dataset.

# %%
world_population_index=world_population.set_index("Capital")

# %%
world_population_index
# Out:
#                   Rank CCA3  Country/Territory Continent  2022 Population  \
# Capital
# Kabul               36  AFG        Afghanistan      Asia         41128771
# Tirana             138  ALB            Albania    Europe          2842321
# Algiers             34  DZA            Algeria    Africa         44903225
# Pago Pago          213  ASM     American Samoa   Oceania            44273
# Andorra la Vella   203  AND            Andorra    Europe            79824
# ...                ...  ...                ...       ...              ...
# Mata-Utu           226  WLF  Wallis and Futuna   Oceania            11572
# El Aaiún           172  ESH     Western Sahara    Africa           575986
# Sanaa               46  YEM              Yemen      Asia         33696614
# Lusaka              63  ZMB             Zambia    Africa         20017675
# Harare              74  ZWE           Zimbabwe    Africa         16320537
#
#                   2020 Population  2015 Population  2010 Population  \
# ...

# %% [markdown]
# ### Changing the index position to set capital as a index

# %%
world_population_index=world_population_index.reset_index()

# %% [markdown]
# ### To view the Conditioned dataset, use the dataset name world_population.

# %%
world_population_index
# Out:
#               Capital  Rank CCA3  Country/Territory Continent  \
# 0               Kabul    36  AFG        Afghanistan      Asia
# 1              Tirana   138  ALB            Albania    Europe
# 2             Algiers    34  DZA            Algeria    Africa
# 3           Pago Pago   213  ASM     American Samoa   Oceania
# 4    Andorra la Vella   203  AND            Andorra    Europe
# ..                ...   ...  ...                ...       ...
# 229          Mata-Utu   226  WLF  Wallis and Futuna   Oceania
# 230          El Aaiún   172  ESH     Western Sahara    Africa
# 231             Sanaa    46  YEM              Yemen      Asia
# 232            Lusaka    63  ZMB             Zambia    Africa
# 233            Harare    74  ZWE           Zimbabwe    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %% [markdown]
# ### Reset the index position.

# %%
world_population_loc=world_population.loc[(world_population.Rank>=150)&(world_population.Continent=='Asia')]

# %%
world_population_loc
# Out:
#      Rank CCA3 Country/Territory              Capital Continent  \
# 15    154  BHR           Bahrain               Manama      Asia
# 23    165  BTN            Bhutan              Thimphu      Asia
# 29    175  BRN            Brunei  Bandar Seri Begawan      Asia
# 119   167  MAC             Macau    Concelho de Macau      Asia
# 123   174  MDV          Maldives                 Malé      Asia
# 207   155  TLS       Timor-Leste                 Dili      Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 15           1472233          1477469          1362142          1213645
# 23            782455           772506           743274           705516
# 29            449002           441725           421437           396053
# 119           695168           676283           615239           557297
# 123           523787           514438           435582           361575
# 207          1341296          1299995          1205813          1088486
#
# ...

# %% [markdown]
# ### Location of continent Asia's rank greater than or equal to 150

# %%
world_population_iloc=world_population.iloc[51:151,2:13]

# %%
world_population_iloc
# Out:
#       Country/Territory        Capital      Continent  2022 Population  \
# 51              Denmark     Copenhagen         Europe          5882261
# 52             Djibouti       Djibouti         Africa          1120849
# 53             Dominica         Roseau  North America            72737
# 54   Dominican Republic  Santo Domingo  North America         11228821
# 55             DR Congo       Kinshasa         Africa         99010212
# ..                  ...            ...            ...              ...
# 146         New Zealand     Wellington        Oceania          5185288
# 147           Nicaragua        Managua  North America          6948392
# 148               Niger         Niamey         Africa         26207977
# 149             Nigeria          Abuja         Africa        218541212
# 150                Niue          Alofi        Oceania             1934
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# ...

# %% [markdown]
# ### Locating of Observations and variables by conditioned dataset.

# %%
world_population_agg=world_population.groupby('Capital')['Growth Rate'].mean()

# %%
world_population_agg
# Out:
# Capital
# Abu Dhabi       1.0081
# Abuja           1.0241
# Accra           1.0196
# Addis Ababa     1.0257
# Algiers         1.0164
#                  ...
# Yamoussoukro    1.0248
# Yaounde         1.0263
# Yaren           1.0125
# Yerevan         0.9962
# Zagreb          0.9927
# Name: Growth Rate, Length: 234, dtype: float64

# %% [markdown]
# ### Groupby aggregate function

# %%
world_population['Continent']=world_population['Continent'].astype('object')

# %% [markdown]
# ### The astype function change the data type of the variables

# %%
world_population['Continent']
# Out:
# 0         Asia
# 1       Europe
# 2       Africa
# 3      Oceania
# 4       Europe
#         ...
# 229    Oceania
# 230     Africa
# 231       Asia
# 232     Africa
# 233     Africa
# Name: Continent, Length: 234, dtype: object
